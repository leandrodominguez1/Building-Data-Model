# %%
# !pip install pandas
# Out:
# ...
#      ---------------------------------------- 10.4/10.4 MB 5.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 14.6/14.6 MB 6.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 500.7/500.7 kB 6.3 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import os

# %%
df = pd.read_csv('C:/Users/Administrador/Downloads/FIFA2014.csv')

# %%
country_code = []
for i in df['Team'].values:
    country_code.append(i[:3].upper())

# %%
country_code
# Out:
# ['GER',
#  'ARG',
#  'NET',
#  'BRA',
#  'COL',
#  'BEL',
#  'FRA',
#  'COS',
#  'CHI',
#  'MEX',
#  'SWI',
#  'URU',
#  'GRE',
#  'ALG',
#  'UNI',
#  'NIG',
#  'ECU',
#  'POR',
#  'CRO',
#  'BOS',
#  'IVO',
#  'ITA',
#  'SPA',
#  'RUS',
#  'GHA',
#  'ENG',
#  'SOU',
#  'IRA',
#  'JAP',
#  'AUS',
#  'HON',
#  'CAM']

# %%
df['Country_code'] = country_code

# %%
df1 = df[['Country_code', 'Win', 'Draw', 'Loss' ]]

# %%
df1
# Out:
#    Country_code  Win  Draw  Loss
# 0           GER    6     1     0
# 1           ARG    5     1     1
# 2           NET    5     2     0
# 3           BRA    3     2     2
# 4           COL    4     0     1
# 5           BEL    4     0     1
# 6           FRA    3     1     1
# 7           COS    2     3     0
# 8           CHI    2     1     1
# 9           MEX    2     1     1
# 10          SWI    2     0     2
# 11          URU    2     0     2
# 12          GRE    1     2     1
# 13          ALG    1     1     2
# 14          UNI    1     1     2
# 15          NIG    1     1     2
# 16          ECU    1     1     1
# 17          POR    1     1     1
# 18          CRO    1     0     2
# 19          BOS    1     0     2
# 20          IVO    1     0     2
# 21          ITA    1     0     2
# 22          SPA    1     0     2
# 23          RUS    0     2     1
# 24          GHA    0     1     2
# 25          ENG    0     1     2
# 26          SOU    0     1     2
# ...

# %%
df2 = df[['Team', 'Country_code', 'Position', 'Points']]

# %%
df2
# Out:
#                       Team Country_code  Position  Points
# 0                  Germany          GER         1      19
# 1                Argentina          ARG         2      16
# 2              Netherlands          NET         3      17
# 3                   Brazil          BRA         4      11
# 4                 Colombia          COL         5      12
# 5                  Belgium          BEL         6      12
# 6                   France          FRA         7      10
# 7               Costa Rica          COS         8       9
# 8                    Chile          CHI         9       7
# 9                   Mexico          MEX        10       7
# 10             Switzerland          SWI        11       6
# 11                 Uruguay          URU        12       6
# 12                  Greece          GRE        13       5
# 13                 Algeria          ALG        14       4
# 14           United States          UNI        15       4
# ...

# %%
df3 = df[['Team', 'Goals For', 'Goals Against', 'Goal Difference']]

# %%
df3
# Out:
#                       Team  Goals For  Goals Against Goal Difference
# 0                  Germany         18              4              14
# 1                Argentina          8              4               4
# 2              Netherlands         15              4              11
# 3                   Brazil         11             14              −3
# 4                 Colombia         12              4               8
# 5                  Belgium          6              3               3
# 6                   France         10              3               7
# 7               Costa Rica          5              2               3
# 8                    Chile          6              4               2
# 9                   Mexico          5              3               2
# 10             Switzerland          7              7               0
# 11                 Uruguay          4              6              −2
# 12                  Greece          3              5              −2
# ...

# %%
df1.to_excel('team_st1.xlsx')
df2.to_excel('team_st2.xlsx')
df3.to_excel('team_st3.xlsx')
